# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
csv_file = '/srv/scratch6/kew/ats/fudge/hpsearch/bart_large_paraNMT_filt_fr-wiki100M_bart_glove/beam/results.csv'
csv_file = '/srv/scratch6/kew/ats/fudge/hpsearch/bart_large_paraNMT_filt_fr-wiki100M_bart_glove/topk5/results.csv'
df = pd.read_csv(csv_file, header=0)

# %%
# df.groupby(by=['data', 'condition_lambda'])

# %%
sns.scatterplot(data=df, x='condition_lambda', style='data', hue='precondition_topk', y='bleu')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.scatterplot(data=df, x='condition_lambda', style='data', hue='precondition_topk', y='sari')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.scatterplot(data=df, x='condition_lambda', style='data', hue='precondition_topk', y='fkgl')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
